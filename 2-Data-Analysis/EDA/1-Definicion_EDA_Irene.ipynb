# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Students' Mental Health"
#https://www.kaggle.com/datasets/ikynahidwin/depression-student-dataset

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "El tema del proyecto consiste en un análisis de la salud mental de los estudiantes en base a diversos factores personales y conductuales"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "La presión academica favorece a una mala salud mental del estudiante"

# %%
# Escribe más hipótesis si las hubiera en Markdown
hipotesis_2 = "La satisfaccion del estudiante con sus resultados no es tan determiante en la salud mental"
hipotesis_3 = "Una mala alimentacion es menos determinante que una buena conducta de sueño en la salud mental"
hipotesis_4 = "El género femenino siente más presion"
hipotesis_5 = "Cuantas más horas de estudio peores hábitos de alimentación y sueño"
hipotesis_6 = "El historial familiar es determinante para padecer depresión"

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_1 = pd.DataFrame()
fuente_1 = ""
# df_2 = pd.DataFrame()
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
# df_1.head()

# %%
# Siguiente dataset...
# df_2.head()
